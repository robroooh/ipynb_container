# %% [markdown]
# python -u convolutional_mlp.py
# The code for file convolutional_mlp.py ran for 4.77m
# GPU memory usage: 457MB
#
# export THEANO_FLAGS=optimizer_including=cudnn
# python -u convolutional_mlp.py
# The code for file convolutional_mlp.py ran for 9.99m
# GPU memory usage: 493MB
#
# export THEANO_FLAGS=optimizer_including=conv_gemm
# python -u convolutional_mlp.py
# The code for file convolutional_mlp.py ran for 3.41m
# GPU memory usage: 585MB
#
# export THEANO_FLAGS=optimizer_including=conv_fft:conv_fft_valid:conv_fft_full
# python -u convolutional_mlp.py
# The code for file convolutional_mlp.py ran for 2.96m
# GPU memory usage: 1469MB

# %%
from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils

import sys, getopt

nb_layers = 1
nb_conv = 3

print([str(a) for a in sys.argv])

# if len(sys.argv) > 1:
#     num_argv = np.array(sys.argv[1:]).astype(np.float)
#     nb_layers = num_argv[1]
#     nb_conv = num_argv[2]
    
batch_size = 128
nb_classes = 10
nb_epoch = 12

# input image dimensions
img_rows, img_cols = 28, 28
# number of convolutional filters to use
nb_filters = 32
# size of pooling area for max pooling
nb_pool = 2

# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

model = Sequential()

model.add(Convolution2D(nb_filters, nb_conv, nb_conv,
                        border_mode='valid',
                        input_shape=(1, img_rows, img_cols)))

if nb_layers > 1:
    for i in range(nb_layers):
        model.add(Convolution2D(nb_filters, nb_conv, nb_conv, border_mode='valid'))


model.add(Activation('relu'))

model.add(Flatten())
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['accuracy'])

model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
          verbose=0, validation_data=(X_test, Y_test))
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# ['/usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py', '-f', '/run/user/1000/jupyter/kernel-8a841d22-e77d-41a2-b9bb-fcd853e4f79e.json']
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# convolution2d_29 (Convolution2D) (None, 32, 26, 26)    320         convolution2d_input_17[0][0]
# ____________________________________________________________________________________________________
# activation_41 (Activation)       (None, 32, 26, 26)    0           convolution2d_29[0][0]
# ____________________________________________________________________________________________________
# flatten_14 (Flatten)             (None, 21632)         0           activation_41[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
all_weights = model.layers[:2].get_weights()

for weight in all_weights:
    print("=============================================================================")
    print("da weight", weight[0])
# Out:
# [array([[[[ -1.01138614e-01,  -2.29321375e-01,  -1.77747354e-01],
#           [  5.54295816e-02,  -2.03331560e-02,   1.67709850e-02],
#           [  5.35477065e-02,   2.47465566e-01,   1.47097096e-01]]],
#
#
#         [[[ -1.23023674e-01,  -6.95959628e-02,  -9.06319008e-04],
#           [ -1.40738189e-01,   7.61154667e-02,  -6.19407557e-02],
#           [  2.96271387e-02,   2.28231139e-02,  -6.85879588e-02]]],
#
#
#         [[[  7.14700222e-02,   1.17975213e-01,   1.47812277e-01],
#           [ -5.49350455e-02,  -5.43591753e-02,   4.22518179e-02],
#           [ -3.73174213e-02,  -1.82183653e-01,  -9.67052281e-02]]],
#
#
#         [[[ -1.43032387e-01,   2.80864481e-02,   1.37400016e-01],
#           [ -3.95282023e-02,   2.53458947e-01,   7.97701180e-02],
#           [  4.78446372e-02,   4.59869094e-02,  -1.64757371e-01]]],
#
#
#         [[[  9.62613970e-02,   1.96487471e-01,  -6.00668415e-02],
#           [ -7.67565519e-02,   5.56789599e-02,   1.48937613e-01],
# ...
